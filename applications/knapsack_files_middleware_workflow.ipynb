# %%
import os
from quantum_serverless import QuantumServerless, Provider, Program
# Out:
# OpenBLAS WARNING - could not determine the L2 cache size on this system, assuming 256k
# OpenBLAS WARNING - could not determine the L2 cache size on this system, assuming 256k
# OpenBLAS WARNING - could not determine the L2 cache size on this system, assuming 256k

# %%
provider = Provider(
#    token="YOUR_TOKEN_FROM_STAGING",
    username="user",
    password="password123",
    host=os.environ.get("GATEWAY_HOST", "http://localhost:8000")
)
provider

serverless = QuantumServerless(provider)
serverless
# Out:
# <QuantumServerless | providers [gateway-provider]>

# %%
program = Program(
    title="Knapsack workflow",
    entrypoint="knapsack_quantum_program.py",
    working_dir="./",
    dependencies=["docplex"]
)

job = serverless.run(program)
job
# Out:
# <Job | 44772cdf-f0ce-44fb-9340-fed2734875e8>

# %%
job.status()
# Out:
# 'SUCCEEDED'

# %%
import json

middleware_res = json.loads(job.result())
print('Solution value:', middleware_res["value"])
print('Solution weight:', middleware_res["weight"])
# Out:
# Solution value: 16.0
# Solution weight: 12.0

# %%
print(job.logs())
# Out:
# OpenBLAS WARNING - could not determine the L2 cache size on this system, assuming 256k
# OpenBLAS WARNING - could not determine the L2 cache size on this system, assuming 256k
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: 0-1 Knapsack problem
#
# Maximize
#  obj: 4 x_0 + 3 x_1 + 5 x_2 + 6 x_3 + 7 x_4
# Subject To
#  c1: 2 x_0 + 2 x_1 + 4 x_2 + 5 x_3 + 6 x_4 <= 12
#
# Bounds
#  0 <= x_0 <= 1
#  0 <= x_1 <= 1
#  0 <= x_2 <= 1
#  0 <= x_3 <= 1
#  0 <= x_4 <= 1
#
# Binaries
#  x_0 x_1 x_2 x_3 x_4
# End
#
# Problem name: 0-1 Knapsack problem
#
# Maximize
#   4*x_0 + 3*x_1 + 5*x_2 + 6*x_3 + 7*x_4
#
# Subject to
#   Linear constraints (1)
#     2*x_0 + 2*x_1 + 4*x_2 + 5*x_3 + 6*x_4 <= 12  'c0'
#
#   Binary variables (5)
#     x_0 x_1 x_2 x_3 x_4
#
# Problem name: 0-1 Knapsack problem
#
# Minimize
#   26*c0@int_slack@0^2 + 104*c0@int_slack@0*c0@int_slack@1
#   + 208*c0@int_slack@0*c0@int_slack@2 + 260*c0@int_slack@0*c0@int_slack@3
# ...
