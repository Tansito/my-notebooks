# %%
import os
from quantum_serverless import QuantumServerless, Provider, Program
# Out:
# OpenBLAS WARNING - could not determine the L2 cache size on this system, assuming 256k
# OpenBLAS WARNING - could not determine the L2 cache size on this system, assuming 256k
# OpenBLAS WARNING - could not determine the L2 cache size on this system, assuming 256k

# %%
provider = Provider(
#    token="YOUR_TOKEN_FROM_STAGING",
    username="user",
    password="password123",
    host=os.environ.get("GATEWAY_HOST", "http://localhost:8000")
)
provider

serverless = QuantumServerless(provider)
serverless
# Out:
# <QuantumServerless | providers [gateway-provider]>

# %%
program = Program(
    title="Basic optimization workflow",
    entrypoint="basic_optimization_quantum_program.py",
    working_dir="./",
    dependencies=["docplex"]
)

job = serverless.run(program)
job
# Out:
# <Job | 3b4b68c5-9f93-4092-88d9-eea62097f79d>

# %%
job.status()
# Out:
# 'SUCCEEDED'

# %%
job.result()
# Out:
# '[0.0, 0.0, 1.0]'

# %%
print(job.logs())
# Out:
# OpenBLAS WARNING - could not determine the L2 cache size on this system, assuming 256k
# OpenBLAS WARNING - could not determine the L2 cache size on this system, assuming 256k
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: docplex model
#
# Minimize
#  obj: x - 2 y - 3 z + [ 2 x*y - 2 x*z + 4 y*z ]/2
# Subject To
#
# Bounds
#  0 <= x <= 1
#  0 <= y <= 1
#  0 <= z <= 1
#
# Binaries
#  x y z
# End
#
# Problem name: docplex model
#
# Minimize
#   x*y - x*z + 2*y*z + x - 2*y - 3*z
#
# Subject to
#   No constraints
#
#   Binary variables (3)
#     x y z
#
# Problem name: docplex model
#
# Minimize
#   x*y - x*z + 2*y*z + x - 2*y - 3*z
#
# Subject to
#   No constraints
#
#   Binary variables (3)
#     x y z
#
# SparsePauliOp(['IIZ', 'IZI', 'ZII', 'IZZ', 'ZIZ', 'ZZI'],
#               coeffs=[-0.5 +0.j,  0.25+0.j,  1.25+0.j,  0.25+0.j, -0.25+0.j,  0.5 +0.j])
#      ┌──────────┐     ┌──────────┐                 ┌──────────┐
# q_0: ┤ Ry(θ[0]) ├──■──┤ Ry(θ[3]) ├──────────────■──┤ Ry(θ[6]) ├────────────
#      ├──────────┤┌─┴─┐└──────────┘┌──────────┐┌─┴─┐└──────────┘┌──────────┐
# q_1: ┤ Ry(θ[1]) ├┤ X ├─────■──────┤ Ry(θ[4]) ├┤ X ├─────■──────┤ Ry(θ[7]) ├
#      ├──────────┤└───┘   ┌─┴─┐    ├──────────┤└───┘   ┌─┴─┐    ├──────────┤
# q_2: ┤ Ry(θ[2]) ├────────┤ X ├────┤ Ry(θ[5]) ├────────┤ X ├────┤ Ry(θ[8]) ├
#      └──────────┘        └───┘    └──────────┘        └───┘    └──────────┘
# global phase: π
#          ┌────┐┌──────────────┐   ┌────┐   ┌────────┐      ┌────┐  »
# q_0 -> 0 ┤ √X ├┤ Rz(θ[0] + π) ├───┤ √X ├───┤ Rz(3π) ├─■────┤ √X ├──»
#          ├────┤├──────────────┤┌──┴────┴──┐└─┬────┬─┘ │ ┌──┴────┴─┐»
# q_1 -> 1 ┤ √X ├┤ Rz(θ[1] + π) ├┤ Rz(-π/2) ├──┤ √X ├───■─┤ Rz(π/2) ├»
#          ├────┤├──────────────┤├──────────┤  ├────┤     └─────────┘»
# q_2 -> 2 ┤ √X ├┤ Rz(θ[2] + π) ├┤ Rz(-π/2) ├──┤ √X ├────────────────»
#          └────┘└──────────────┘└──────────┘  └────┘                »
# «         ┌──────────────┐   ┌────┐  ┌────────┐                          »
# «q_0 -> 0 ┤ Rz(θ[3] + π) ├───┤ √X ├──┤ Rz(3π) ├──────────────────────────»
# «         └────┬────┬────┘┌──┴────┴─┐└────────┘  ┌────┐  ┌──────────────┐»
# «q_1 -> 1 ─────┤ √X ├─────┤ Rz(π/2) ├────■───────┤ √X ├──┤ Rz(θ[4] + π) ├»
# «              └────┘     └─────────┘    │     ┌─┴────┴─┐└────┬────┬────┘»
# «q_2 -> 2 ───────────────────────────────■─────┤ Rz(-π) ├─────┤ √X ├─────»
# «                                              └────────┘     └────┘     »
# «                                                    ┌────┐  ┌──────────────┐»
# «q_0 -> 0 ─────────────────────────────────■─────────┤ √X ├──┤ Rz(θ[6] + π) ├»
# «         ┌──────────┐     ┌────┐          │      ┌──┴────┴─┐└────┬────┬────┘»
# «q_1 -> 1 ┤ Rz(-π/2) ├─────┤ √X ├──────────■──────┤ Rz(π/2) ├─────┤ √X ├─────»
# «         ├─────────┬┘┌────┴────┴────┐┌──────────┐└──┬────┬─┘     └────┘     »
# «q_2 -> 2 ┤ Rz(π/2) ├─┤ Rz(θ[5] + π) ├┤ Rz(-π/2) ├───┤ √X ├──────────────────»
# «         └─────────┘ └──────────────┘└──────────┘   └────┘                  »
# «            ┌────┐  ┌────────┐                                     »
# «q_0 -> 0 ───┤ √X ├──┤ Rz(3π) ├─────────────────────────────────────»
# «         ┌──┴────┴─┐└────────┘  ┌────┐  ┌──────────────┐   ┌────┐  »
# «q_1 -> 1 ┤ Rz(π/2) ├────■───────┤ √X ├──┤ Rz(θ[7] + π) ├───┤ √X ├──»
# «         └─────────┘    │     ┌─┴────┴─┐└────┬────┬────┘┌──┴────┴─┐»
# «q_2 -> 2 ───────────────■─────┤ Rz(-π) ├─────┤ √X ├─────┤ Rz(π/2) ├»
# «                              └────────┘     └────┘     └─────────┘»
# «
# «q_0 -> 0 ────────────────────────────────
# «            ┌────────┐
# «q_1 -> 1 ───┤ Rz(3π) ├───────────────────
# «         ┌──┴────────┴──┐┌────┐┌────────┐
# «q_2 -> 2 ┤ Rz(θ[8] + π) ├┤ √X ├┤ Rz(3π) ├
# «         └──────────────┘└────┘└────────┘
# SparsePauliOp(['IIZ', 'IZI', 'ZII', 'IZZ', 'ZIZ', 'ZZI'],
#               coeffs=[-0.5 +0.j,  0.25+0.j,  1.25+0.j,  0.25+0.j, -0.25+0.j,  0.5 +0.j])
#  message: Optimization terminated successfully.
#  success: True
#      fun: -1.4989456319533923
#        x: [ 3.249e+00  1.732e+00  1.519e+00  3.932e-01 -1.851e-01
#            -1.232e-02  2.593e+00  2.166e+00  1.482e+00]
#      nit: 100
#     nfev: 200
